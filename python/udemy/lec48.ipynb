# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import  stats

import matplotlib as mpl
import matplotlib.pyplot as  plt
import seaborn as sns

# %matplotlib inline

# %%
dataset1 = randn(100)
plt.hist(dataset1)
# Out:
# (array([ 1.,  5.,  8., 11., 15., 16., 15., 11.,  7., 11.]),
#  array([-2.14123564, -1.7583417 , -1.37544777, -0.99255383, -0.6096599 ,
#         -0.22676597,  0.15612797,  0.5390219 ,  0.92191584,  1.30480977,
#          1.6877037 ]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 1.,  4.,  7.,  7., 11., 10., 12., 15., 10.,  3.]),
#  array([-2.54762375, -2.11621916, -1.68481456, -1.25340997, -0.82200538,
#         -0.39060079,  0.0408038 ,  0.47220839,  0.90361298,  1.33501757,
#          1.76642217]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, density=True)
# Out:
# (array([0.02611689, 0.13058447, 0.20893515, 0.28728583, 0.3917534 ,
#         0.41787029, 0.3917534 , 0.28728583, 0.18281825, 0.28728583]),
#  array([-2.14123564, -1.7583417 , -1.37544777, -0.99255383, -0.6096599 ,
#         -0.22676597,  0.15612797,  0.5390219 ,  0.92191584,  1.30480977,
#          1.6877037 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,density=True,alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20, color='indianred')
# Out:
# (array([0.05795024, 0.        , 0.17385072, 0.05795024, 0.11590048,
#         0.2897512 , 0.23180096, 0.17385072, 0.23180096, 0.40565169,
#         0.40565169, 0.17385072, 0.40565169, 0.2897512 , 0.52155217,
#         0.34770145, 0.40565169, 0.17385072, 0.11590048, 0.05795024]),
#  array([-2.54762375, -2.33192145, -2.11621916, -1.90051686, -1.68481456,
#         -1.46911227, -1.25340997, -1.03770768, -0.82200538, -0.60630309,
#         -0.39060079, -0.1748985 ,  0.0408038 ,  0.2565061 ,  0.47220839,
#          0.68791069,  0.90361298,  1.11931528,  1.33501757,  1.55071987,
#          1.76642217]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)
sns.jointplot(data1,data2)
# Out:
# /Users/inagakidaisuke/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/inagakidaisuke/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(data1,data2,kind='hex')
# Out:
# /Users/inagakidaisuke/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/inagakidaisuke/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
